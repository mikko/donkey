# %% [markdown]
# # Example of Markku.ai

# %%
import glob

# %% [markdown]
# # Data loading

# %%
tub_names = "./data/augmented"
tubs = glob.glob(str('%s/**' % tub_names), recursive=True)
print(tubs)
# Out:
# ['./data/augmented/', './data/augmented/1', './data/augmented/1/3_bright', './data/augmented/1/3_bright/387_bright.jpg', './data/augmented/1/3_bright/record_997.json', './data/augmented/1/3_bright/698_bright.jpg', './data/augmented/1/3_bright/record_978.json', './data/augmented/1/3_bright/record_581.json', './data/augmented/1/3_bright/record_1118.json', './data/augmented/1/3_bright/293_bright.jpg', './data/augmented/1/3_bright/record_702.json', './data/augmented/1/3_bright/record_1231.json', './data/augmented/1/3_bright/record_352.json', './data/augmented/1/3_bright/948_bright.jpg', './data/augmented/1/3_bright/1295_bright.jpg', './data/augmented/1/3_bright/record_647.json', './data/augmented/1/3_bright/record_217.json', './data/augmented/1/3_bright/record_539.json', './data/augmented/1/3_bright/198_bright.jpg', './data/augmented/1/3_bright/record_169.json', './data/augmented/1/3_bright/record_493.json', './data/augmented/1/3_bright/809_bright.jpg', './data/augmented/1/3_bright/487_b
# ...
